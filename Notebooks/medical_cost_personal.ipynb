# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavocoderjs/An-lise-de-Dados-/blob/main/medical_cost_personal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mirichoi0218/insurance")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/insurance

# %%
import os

# Listar arquivos dentro da pasta
print(os.listdir(path))
# Out:
# ['insurance.csv']

# %%
import pandas as pd

file_path = os.path.join(path, 'insurance.csv')
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 191    36  female  26.200         0     no  southwest   4883.86600
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 502    51    male  23.210         1    yes  southeast  22218.11490
# 1258   55    male  37.715         3     no  northwest  30063.58055
# 1056   48  female  28.900         0     no  southwest   8277.52300
# 357    47    male  29.830         3     no  northwest   9620.33070
# 203    27  female  36.080         0    yes  southeast  37133.89820
# 478    21    male  36.850         0     no  southeast   1534.30450
# 124    47  female  33.915         3     no  northwest  10115.00885
# 667    40  female  32.775         2    yes  northwest  40003.33225

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Melhor visualização dos gráficos
sns.set(style="whitegrid")

# %%
df.shape         # Linhas e colunas
# Out:
# (1338, 7)

# %%
df.columns       # Nomes das colunas
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.info()        # Tipos de dados e valores nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()    # Estatísticas para colunas numéricas
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()         # Ver quantos valores nulos por coluna
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()     # Ver se há linhas duplicadas
# Out:
# np.int64(1)

# %%
df['charges'].hist(bins=30)
plt.title("Distribuição dos custos de seguro")
plt.xlabel("Valor ($)")
plt.ylabel("Número de pessoas")
plt.show()

# %%
sns.boxplot(y=df['bmi'])
plt.title("Boxplot do IMC")
plt.show()

# %%
df['smoker'].value_counts().plot(kind='bar')
plt.title("Fumantes vs Não fumantes")
plt.ylabel("Quantidade")
plt.show()

# %%
sns.boxplot(x='smoker', y='charges', data=df)
plt.title("Custo de seguro por hábito de fumar")
plt.show()

# %%
sns.scatterplot(x='bmi', y='charges', data=df)
plt.title("IMC vs Custo de seguro")
plt.show()

# %%
sns.pairplot(df, hue='smoker')
plt.show()

# Correlação entre variáveis numéricas
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Mapa de calor das correlações")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-441631235.py in <cell line: 0>()
#       4 # Correlação entre variáveis numéricas
#       5 plt.figure(figsize=(8,6))
# ----> 6 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#       7 plt.title("Mapa de calor das correlações")
#       8 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# ...

# %%
sns.boxplot(x='charges', data=df)
plt.title("Boxplot dos custos médicos")
plt.show()
