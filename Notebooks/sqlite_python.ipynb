# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavocoderjs/An-lise-de-Dados-/blob/main/sqlite_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# Conectar ao banco de dados SQLite
connection = sqlite3.connect('example.db')
cursor = connection.cursor()

# Criar a tabela 'employees' se não existir
cursor.execute('''
CREATE TABLE IF NOT EXISTS employees(
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    age INTEGER,
    department TEXT
)
''')

# Inserir um registro na tabela
cursor.execute('''
INSERT INTO employees(name, age, department)
VALUES('Krish', 32, 'Data Scientist')
''')

# Confirmar as alterações
connection.commit()

# Consultar todos os registros da tabela
cursor.execute('SELECT * FROM employees')
rows = cursor.fetchall()

# Exibir os registros
for row in rows:
    print(row)
# Out:
# (1, 'Krish', 32, 'Data Scientist')
